# %%
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector


def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
Language.factory("language_detector01", func=get_lang_detector)
nlp.add_pipe('language_detector01', last=True)
text = 'hello word'
doc = nlp(text)
print(doc._.language)
# Out:
# 2022-02-01 21:29:15.319990: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-01 21:29:15.320025: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# {'language': 'nl', 'score': 0.99999496210014}

# %%
import pandas as pd

df = pd.read_csv('../raw_data/concat.csv')

df
# Out:
# /home/alechenwolf/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (1,2) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                                                name        date  \
# 0       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 1       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 2       Expansion - Hearts of Iron IV: Man the Guns  2019-02-07
# 3                                  Dead by Daylight  2018-06-14
# 4                                  Dead by Daylight  2017-06-20
# ...                                             ...         ...
# 575711                                         zika         NaN
# 575712                                         zika         NaN
# 575713                                         zika         NaN
# ...

# %%
df_sample = df.iloc[0: 100]

# %%
# %%time

reviews = df_sample['review']

reviews2 = [nlp(str(row))._.language['language'] for row in reviews]
# Out:
# CPU times: user 1.72 s, sys: 47.8 ms, total: 1.76 s
# Wall time: 1.76 s

# %%
reviews2
# Out:
# ['en',
#  'tr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'nl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'de',
#  'so',
#  'en',
#  'es',
#  'tl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'pt',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tl',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'so',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'tr',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en',
#  'en']
