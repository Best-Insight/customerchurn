# %%
import pandas as pd
import numpy as np

# %%
data_steam = pd.read_csv('../raw_data/steam_reviews.csv')

data_steam.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 434891 entries, 0 to 434890
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   date_posted             434891 non-null  object
#  1   funny                   434891 non-null  int64
#  2   helpful                 434891 non-null  int64
#  3   hour_played             434891 non-null  int64
#  4   is_early_access_review  434891 non-null  bool
#  5   recommendation          434891 non-null  object
#  6   review                  433375 non-null  object
#  7   title                   434891 non-null  object
# dtypes: bool(1), int64(3), object(4)
# memory usage: 23.6+ MB

# %%
data_steam.recommendation.value_counts()
# Out:
# Recommended        303593
# Not Recommended    131298
# Name: recommendation, dtype: int64

# %%
data_steam.review
# Out:
# 0         &gt Played as German Reich&gt Declare war on B...
# 1                                                      yes.
# 2         Very good game although a bit overpriced in my...
# 3         Out of all the reviews I wrote This one is pro...
# 4         Disclaimer I survivor main. I play games for f...
#                                 ...
# 434886    YOUR FLESH WILL ROT AND DECAY.STEEL IS IMMORTA...
# 434887    Domini and Dominae I believe what we are deali...
# 434888    First off if you like X Com style of games you...
# 434889    As a disclaimer I'm an AdMech player on the ta...
# 434890    Don't listen to people who claim it's the game...
# Name: review, Length: 434891, dtype: object

# %%
data_bank = pd.read_csv('../raw_data/bank_reviews.csv', encoding_errors='ignore')

# %%
data_bank.head()
# Out:
#          Date  Stars                                            Reviews  \
# 0  10-04-2017      5  Great job, Wyndham Capital! Each person was pr...
# 1  10-02-2017      5  Matthew Richardson is professional and helpful...
# 2  21-08-2017      5  We had a past experience with Wyndham Mortgage...
# 3  17-12-2017      5  We have been dealing with Brad Thomka from the...
# 4  27-05-2016      5  I can't express how grateful I am for the supp...
#
#                    BankName
# 0  Wyndham Capital Mortgage
# 1  Wyndham Capital Mortgage
# 2  Wyndham Capital Mortgage
# 3  Wyndham Capital Mortgage
# 4  Wyndham Capital Mortgage

# %%
data_coursera_by_course = pd.read_csv('../raw_data/coursera_by_course_reviews.csv')

# %%
data_coursera_by_course.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140320 entries, 0 to 140319
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   CourseId  140320 non-null  object
#  1   Review    140317 non-null  object
#  2   Label     140320 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 3.2+ MB

# %%
data_coursera_reviews = pd.read_csv('../raw_data/coursera_reviews.csv')

# %%
data_coursera_reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107018 entries, 0 to 107017
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Id      107018 non-null  int64
#  1   Review  107018 non-null  object
#  2   Label   107018 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 2.4+ MB

# %%
data_coursera_reviews.head()
# Out:
#    Id                                             Review  Label
# 0   0                               good and interesting      5
# 1   1  This class is very helpful to me. Currently, I...      5
# 2   2  like!Prof and TAs are helpful and the discussi...      5
# 3   3  Easy to follow and includes a lot basic and im...      5
# 4   4  Really nice teacher!I could got the point eazl...      4

# %%
data_coursera_inner_merge = data_coursera_reviews.merge(data_coursera_by_course, how = 'inner', on='Review')

# %%
data_coursera_by_course.head()
# Out:
#      CourseId                                             Review  Label
# 0  2-speed-it                                             BOring      1
# 1  2-speed-it                                            Bravo !      5
# 2  2-speed-it                                           Very goo      5
# 3  2-speed-it  Great course - I recommend it for all, especia...      5
# 4  2-speed-it    One of the most useful course on IT Management!      5

# %%
pd.concat([data_coursera_by_course, data_coursera_reviews]).Review.drop_duplicates().shape
# Out:
# (123241,)

# %%
pd.concat([data_coursera_by_course, data_coursera_reviews]).Review.shape
# Out:
# (247338,)

# %%
data_insurance = pd.read_csv('../raw_data/insurance_reviews.csv')

data_insurance.head()
# Out:
#    Unnamed: 0      Customer Name Customer Location  \
# 0           0    Sarah Hoelscher                US
# 1           1      Bruce Winslow                CR
# 2           2      Kelly Wilmeth                US
# 3           3  Stephanie LeBlanc                US
# 4           4                JPD                US
#
#                                          Review Text
# 0                  Easy to use and understand! Qu...
# 1                  It was a real pleasure to spea...
# 2                  Byron Preston was super helpfu...
# 3                  Byron Preston was amazing walk...
# 4                  Thanks Josh, top rate service ...

# %%
# pandas.concat(objs, axis=0, join='outer', ignore_index=False,
#               keys=None, levels=None, names=None, verify_integrity=False, sort=False, copy=True)

# %%
feature = ['title', 'date_posted', 'recommendation', 'review', 'hour_played']

data = data_steam[feature]

# %%
name = ['name', 'date', 'recommendation', 'review', 'playing_hours']

data.columns = name

# %%
data = data.assign(source='steam')

# %%
data_steam = data.assign(stars=None)

# %%
data_steam
# Out:
#                                                name        date  \
# 0       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 1       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 2       Expansion - Hearts of Iron IV: Man the Guns  2019-02-07
# 3                                  Dead by Daylight  2018-06-14
# 4                                  Dead by Daylight  2017-06-20
# ...                                             ...         ...
# 434886                 Warhammer 40,000: Mechanicus  2018-11-17
# 434887                 Warhammer 40,000: Mechanicus  2018-11-17
# 434888                 Warhammer 40,000: Mechanicus  2018-11-20
# 434889                 Warhammer 40,000: Mechanicus  2018-11-18
# 434890                 Warhammer 40,000: Mechanicus  2019-01-21
#
#        recommendation                                             review  \
# 0         Recommended  &gt Played as German Reich&gt Declare war on B...
# ...

# %%
name_bank = ['date', 'stars', 'review', 'name']

data_bank.columns = name_bank

# %%
data_bank
# Out:
#            date  stars                                             review  \
# 0    10-04-2017      5  Great job, Wyndham Capital! Each person was pr...
# 1    10-02-2017      5  Matthew Richardson is professional and helpful...
# 2    21-08-2017      5  We had a past experience with Wyndham Mortgage...
# 3    17-12-2017      5  We have been dealing with Brad Thomka from the...
# 4    27-05-2016      5  I can't express how grateful I am for the supp...
# ..          ...    ...                                                ...
# 500  06-02-2016      1  \r\nI never write reviews but had to this time...
# 501  25-07-2016      1  \r\nIt all started when Bob G ran a credit che...
# 502  27-09-2017      1  \r\nWhat a horrible experience. We have excell...
# 503  24-12-2017      1  \r\nRep was extremely professional, friendly, ...
# 504  19-03-2017      1  \r\nI was working with a loan consultant from ...
#
#                             name
# 0       Wyndham Capital Mortgage
# ...

# %%
data_bank = data_bank.assign(source='bank')

# %%
data_bank = data_bank.assign(playing_hours = None)

# %%
data_bank = data_bank.assign(recommendation = None)

# %%
data_bank
# Out:
#            date  stars                                             review  \
# 0    10-04-2017      5  Great job, Wyndham Capital! Each person was pr...
# 1    10-02-2017      5  Matthew Richardson is professional and helpful...
# 2    21-08-2017      5  We had a past experience with Wyndham Mortgage...
# 3    17-12-2017      5  We have been dealing with Brad Thomka from the...
# 4    27-05-2016      5  I can't express how grateful I am for the supp...
# ..          ...    ...                                                ...
# 500  06-02-2016      1  \r\nI never write reviews but had to this time...
# 501  25-07-2016      1  \r\nIt all started when Bob G ran a credit che...
# 502  27-09-2017      1  \r\nWhat a horrible experience. We have excell...
# 503  24-12-2017      1  \r\nRep was extremely professional, friendly, ...
# 504  19-03-2017      1  \r\nI was working with a loan consultant from ...
#
#                             name source playing_hours recommendation
# ...

# %%
data_coursera_by_course

name = ['name', 'review', 'stars']

data_coursera_by_course.columns = name

# %%
data_coursera_by_course = data_coursera_by_course.assign(
    playing_hours = None,
    recommendation = None,
    source = 'coursera',
    date = None
)

# %%
data_coursera_by_course
# Out:
#               name                                             review  stars  \
# 0       2-speed-it                                             BOring      1
# 1       2-speed-it                                            Bravo !      5
# 2       2-speed-it                                           Very goo      5
# 3       2-speed-it  Great course - I recommend it for all, especia...      5
# 4       2-speed-it    One of the most useful course on IT Management!      5
# ...            ...                                                ...    ...
# 140315        zika  Trendy topic with talks from expertises in the...      4
# 140316        zika  Wonderful! Simple and clear language, good ins...      5
# 140317        zika   an interesting and fun course. thanks. dr quincy      5
# 140318        zika  very broad perspective, up to date information...      4
# 140319        zika  An informative course on the social and financ...      4
#
# ...

# %%
data_insurance

name_insurance = ['']

# %%
data = pd.concat([data_steam, data_bank, data_coursera_by_course])

# %%
# data.to_csv('../raw_data/concat.csv', index=False)

# %%
data
# Out:
#                                                name        date  \
# 0       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 1       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 2       Expansion - Hearts of Iron IV: Man the Guns  2019-02-07
# 3                                  Dead by Daylight  2018-06-14
# 4                                  Dead by Daylight  2017-06-20
# ...                                             ...         ...
# 140315                                         zika        None
# 140316                                         zika        None
# 140317                                         zika        None
# 140318                                         zika        None
# 140319                                         zika        None
#
#        recommendation                                             review  \
# 0         Recommended  &gt Played as German Reich&gt Declare war on B...
# ...

# %%
import spacy
from spacy.language import Language
from spacy_langdetect import LanguageDetector

def get_lang_detector(nlp, name):
    return LanguageDetector()

nlp = spacy.load("en_core_web_sm")
Language.factory("language_detector01", func=get_lang_detector)
nlp.add_pipe('language_detector01', last=True)
text = 'hello word'
doc = nlp(text)
print(doc._.language)
# Out:
# 2022-02-01 19:37:30.059657: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-02-01 19:37:30.059690: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# {'language': 'nl', 'score': 0.9999946214682884}

# %%
len(data['review'])
# Out:
# 575716

# %%
data['review'].iloc[0]
# Out:
# "&gt Played as German Reich&gt Declare war on Belgium&gt Can't break Belgium so go through France&gt Capitulate France in order to get to Belgium&gt Get True Blitzkrieg achievementThis game is dad"

# %%
languages = []

for i in range(len(data['review'])):
    text = str(data['review'].iloc[i])
    doc = nlp(text)
    languages.append(doc._.language)

# %%
data['language'] = data['review'].apply(lambda row: nlp(str(row))._.language)

# %%
reviews = data['review']

reviews2 = [nlp(str(row))._.language['language'] for row in reviews]

# %%
data['language'] = reviews2

# %%
data.to_csv('../')
# Out:
#                                                name        date  \
# 0       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 1       Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 2       Expansion - Hearts of Iron IV: Man the Guns  2019-02-07
# 3                                  Dead by Daylight  2018-06-14
# 4                                  Dead by Daylight  2017-06-20
# ...                                             ...         ...
# 140315                                         zika        None
# 140316                                         zika        None
# 140317                                         zika        None
# 140318                                         zika        None
# 140319                                         zika        None
#
#        recommendation                                             review  \
# 0         Recommended  &gt Played as German Reich&gt Declare war on B...
# ...
