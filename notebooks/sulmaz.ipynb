# %%
import pandas as pd

# %%
pd.read_csv('../../raw_data/concat.csv')
# Out:
#        Unnamed: 0                                         name        date  \
# 0               0  Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 1               1  Expansion - Hearts of Iron IV: Man the Guns  2019-02-10
# 2               2  Expansion - Hearts of Iron IV: Man the Guns  2019-02-07
# 3               3                             Dead by Daylight  2018-06-14
# 4               4                             Dead by Daylight  2017-06-20
# ...           ...                                          ...         ...
# 76096       76096                               Rocket League®  2018-02-26
# 76097       76097                               Rocket League®  2016-05-15
# 76098       76098                               Rocket League®  2016-05-15
# 76099       76099                               Rocket League®  2016-09-17
# 76100           7                                          NaN         NaN
#
# ...
